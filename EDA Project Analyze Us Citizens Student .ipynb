# %% [markdown]
# ___
#
# <p style="text-align: center;"><img src="https://techproeducation.com/wp-content/uploads/2022/01/Calisma-Yuzeyi-1-kopya-5-1-768x126.png" class="img-fluid"
# alt="TECHPRO"></p>
#
# ## <p style="background-color:#FDFEFE; font-family:Arial; color:#47AC34; font-size:100%; text-align:center; border-radius:10px 10px;">WAY TO REINVENT YOURSELF</p>
#
# ## <p style="background-color:#FDFEFE; font-family:Arial; color:#060108; font-size:200%; text-align:center; border-radius:10px 10px;">Data Analysis & Visualization with Python</p>
#
# ## <p style="background-color:#FDFEFE; font-family:Arial; color:#060108; font-size:200%; text-align:center; border-radius:10px 10px;">Project Solution</p>
#
# ![image.png](https://i.ibb.co/mT1GG7j/US-citizen.jpg)
#
# ## <p style="background-color:#FDFEFE; font-family:Arial; color:#060108; font-size:200%; text-align:center; border-radius:10px 10px;">Analysis of US Citizens by Income Levels</p>

# %% [markdown]
# <a id="toc"></a>
#
# ## <p style="background-color:#47AC34; font-family:Georgia; color:#FFFFFF; font-size:175%; text-align:center; border-radius:10px 10px;">Content</p>
#
# * [Introduction](#0)
# * [Dataset Info](#1)
# * [Importing Related Libraries](#2)
# * [Recognizing & Understanding Data](#3)
# * [Univariate & Multivariate Analysis](#4)
# * [Other Specific Analysis Questions](#5)
# * [Dropping Similar & Unneccessary Features](#6)
# * [Handling with Missing Values](#7)
# * [Handling with Outliers](#8)
# * [Final Step to make ready dataset for ML Models](#9)
# * [The End of the Project](#10)

# %% [markdown]
# ## <p style="background-color:#47AC34; font-family:Georgia; color:#FFF9ED; font-size:175%; text-align:center; border-radius:10px 10px;">Introduction</p>
#
# <a id="0"></a>
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true"
# style="color:#FFF9ED; background-color:#47AC34" data-toggle="popover">Content</a>
#
# One of the most important components to any data science experiment that doesn’t get as much importance as it should is **``Exploratory Data Analysis (EDA)``**. In short, EDA is **``"A first look at the data"``**. It is a critical step in analyzing the data from an experiment. It is used to understand and summarize the content of the dataset to ensure that the features which we feed to our machine learning algorithms are refined and we get valid, correctly interpreted results.
# In general, looking at a column of numbers or a whole spreadsheet and determining the important characteristics of the data can be very tedious and boring. Moreover, it is good practice to understand the problem statement and the data before you get your hands dirty, which in view, helps to gain a lot of insights. I will try to explain the concept using the Adult dataset/Census Income dataset available on the [UCI Machine Learning Repository](https://archive.ics.uci.edu/ml/datasets/Adult). The problem statement here is to predict whether the income exceeds 50k a year or not based on the census data.
#
# # Aim of the Project
#
# Applying Exploratory Data Analysis (EDA) and preparing the data to implement the Machine Learning Algorithms;
# 1. Analyzing the characteristics of individuals according to income groups
# 2. Preparing data to create a model that will predict the income levels of people according to their characteristics (So the "salary" feature is the target feature)

# %% [markdown]
# ## <p style="background-color:#47AC34; font-family:newtimeroman; color:#FFF9ED; font-size:175%; text-align:center; border-radius:10px 10px;">Dataset Info</p>
#
# <a id="1"></a>
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true"
# style="color:20b2aa; background-color:#47AC34" data-toggle="popover">Content</a>
#
# The Census Income dataset has 48,842 entries. Each entry contains the following information about an individual:
#
# - **salary (target feature/label):** whether or not an individual makes more than $50,000 annually. (<= 50K, >50K)
# - **age:** the age of an individual. (Integer greater than 0)
# - **workclass:** a general term to represent the employment status of an individual. (Private, Self-emp-not-inc, Self-emp-inc, Federal-gov, Local-gov, State-gov, Without-pay, Never-worked)
# - **fnlwgt:** this is the number of people the census believes the entry represents. People with similar demographic characteristics should have similar weights.  There is one important caveat to remember about this statement. That is that since the CPS sample is actually a collection of 51 state samples, each with its own probability of selection, the statement only applies within state.(Integer greater than 0)
# - **education:** the highest level of education achieved by an individual. (Bachelors, Some-college, 11th, HS-grad, Prof-school, Assoc-acdm, Assoc-voc, 9th, 7th-8th, 12th, Masters, 1st-4th, 10th, Doctorate, 5th-6th, Preschool.)
# - **education-num:** the highest level of education achieved in numerical form. (Integer greater than 0)
# - **marital-status:** marital status of an individual. Married-civ-spouse corresponds to a civilian spouse while Married-AF-spouse is a spouse in the Armed Forces. Married-spouse-absent includes married people living apart because either the husband or wife was employed and living at a considerable distance from home (Married-civ-spouse, Divorced, Never-married, Separated, Widowed, Married-spouse-absent, Married-AF-spouse)
# - **occupation:** the general type of occupation of an individual. (Tech-support, Craft-repair, Other-service, Sales, Exec-managerial, Prof-specialty, Handlers-cleaners, Machine-op-inspct, Adm-clerical, Farming-fishing, Transport-moving, Priv-house-serv, Protective-serv, Armed-Forces)
# - **relationship:** represents what this individual is relative to others. For example an individual could be a Husband. Each entry only has one relationship attribute. (Wife, Own-child, Husband, Not-in-family, Other-relative, Unmarried)
# - **race:** Descriptions of an individual’s race. (White, Asian-Pac-Islander, Amer-Indian-Eskimo, Other, Black)
# - **sex:** the biological sex of the individual. (Male, female)
# - **capital-gain:** capital gains for an individual. (Integer greater than or equal to 0)
# - **capital-loss:** capital loss for an individual. (Integer greater than or equal to 0)
# - **hours-per-week:** the hours an individual has reported to work per week. (continuous)
# - **native-country:** country of origin for an individual (United-States, Cambodia, England, Puerto-Rico, Canada, Germany, Outlying-US(Guam-USVI-etc), India, Japan, Greece, South, China, Cuba, Iran, Honduras, Philippines, Italy, Poland, Jamaica, Vietnam, Mexico, Portugal, Ireland, France, Dominican-Republic, Laos, Ecuador, Taiwan, Haiti, Columbia, Hungary, Guatemala, Nicaragua, Scotland, Thailand, Yugoslavia, El-Salvador, Trinadad&Tobago, Peru, Hong, Holand-Netherlands)

# %% [markdown]
# ## <p style="background-color:#47AC34; font-family:Georgia; color:#FFF9ED; font-size:175%; text-align:center; border-radius:10px 10px;">Importing Related Libraries</p>
#
# <a id="2"></a>
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true"
# style="color:20b2aa; background-color:#47AC34" data-toggle="popover">Content</a>
#
# Once you've installed NumPy & Pandas you can import them as a library:

# %%
# !pip install plotly
# !pip install dash
# !pip install wordcloud
# !pip install cufflinks
# !pip install missingno
# Out:
# Requirement already satisfied: plotly in c:\users\kbker\appdata\local\programs\python\python310\lib\site-packages (5.11.0)
# Requirement already satisfied: tenacity>=6.2.0 in c:\users\kbker\appdata\local\programs\python\python310\lib\site-packages (from plotly) (8.1.0)
# Requirement already satisfied: dash in c:\users\kbker\appdata\local\programs\python\python310\lib\site-packages (2.7.0)
# Requirement already satisfied: dash-core-components==2.0.0 in c:\users\kbker\appdata\local\programs\python\python310\lib\site-packages (from dash) (2.0.0)
# Requirement already satisfied: dash-html-components==2.0.0 in c:\users\kbker\appdata\local\programs\python\python310\lib\site-packages (from dash) (2.0.0)
# Requirement already satisfied: plotly>=5.0.0 in c:\users\kbker\appdata\local\programs\python\python310\lib\site-packages (from dash) (5.11.0)
# Requirement already satisfied: dash-table==5.0.0 in c:\users\kbker\appdata\local\programs\python\python310\lib\site-packages (from dash) (5.0.0)
# Requirement already satisfied: Flask>=1.0.4 in c:\users\kbker\appdata\local\programs\python\python310\lib\site-packages (from dash) (2.2.2)
# Requirement already satisfied: click>=8.0 in c:\users\kbker\appdata\local\programs\python\python310\lib\site-packages (from Flask>=1.0.4->dash) (8.1.3)
# Requirement already satisfied: Jinja2>=3.0 in c:\users\kbker\appdata\local\programs\python\python310\lib\site-packages (from Flask>=1.0.4->dash) (3.1.2)
# Requirement already satisfied: itsdangerous>=2.0 in c:\users\kbker\appdata\local\programs\python\python310\lib\site-packages (from Flask>=1.0.4->dash) (2.1.2)
# Requirement already satisfied: Werkzeug>=2.2.2 in c:\users\kbker\appdata\local\programs\python\python310\lib\site-packages (from Flask>=1.0.4->dash) (2.2.2)
# Requirement already satisfied: tenacity>=6.2.0 in c:\users\kbker\appdata\local\programs\python\python310\lib\site-packages (from plotly>=5.0.0->dash) (8.1.0)
# Requirement already satisfied: colorama in c:\users\kbker\appdata\local\programs\python\python310\lib\site-packages (from click>=8.0->Flask>=1.0.4->dash) (0.4.5)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\kbker\appdata\local\programs\python\python310\lib\site-packages (from Jinja2>=3.0->Flask>=1.0.4->dash) (2.1.1)
# Requirement already satisfied: wordcloud in c:\users\kbker\appdata\local\programs\python\python310\lib\site-packages (1.8.2.2)
# Requirement already satisfied: matplotlib in c:\users\kbker\appdata\local\programs\python\python310\lib\site-packages (from wordcloud) (3.6.2)
# Requirement already satisfied: pillow in c:\users\kbker\appdata\local\programs\python\python310\lib\site-packages (from wordcloud) (9.3.0)
# Requirement already satisfied: numpy>=1.6.1 in c:\users\kbker\appdata\local\programs\python\python310\lib\site-packages (from wordcloud) (1.23.4)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\kbker\appdata\local\programs\python\python310\lib\site-packages (from matplotlib->wordcloud) (3.0.9)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\kbker\appdata\local\programs\python\python310\lib\site-packages (from matplotlib->wordcloud) (1.4.4)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\kbker\appdata\local\programs\python\python310\lib\site-packages (from matplotlib->wordcloud) (2.8.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\kbker\appdata\local\programs\python\python310\lib\site-packages (from matplotlib->wordcloud) (0.11.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\kbker\appdata\local\programs\python\python310\lib\site-packages (from matplotlib->wordcloud) (21.3)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\kbker\appdata\local\programs\python\python310\lib\site-packages (from matplotlib->wordcloud) (4.38.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\kbker\appdata\local\programs\python\python310\lib\site-packages (from matplotlib->wordcloud) (1.0.6)
# Requirement already satisfied: six>=1.5 in c:\users\kbker\appdata\local\programs\python\python310\lib\site-packages (from python-dateutil>=2.7->matplotlib->wordcloud) (1.16.0)
# Requirement already satisfied: cufflinks in c:\users\kbker\appdata\local\programs\python\python310\lib\site-packages (0.17.3)
# Requirement already satisfied: numpy>=1.9.2 in c:\users\kbker\appdata\local\programs\python\python310\lib\site-packages (from cufflinks) (1.23.4)
# Requirement already satisfied: pandas>=0.19.2 in c:\users\kbker\appdata\local\programs\python\python310\lib\site-packages (from cufflinks) (1.5.1)
# Requirement already satisfied: plotly>=4.1.1 in c:\users\kbker\appdata\local\programs\python\python310\lib\site-packages (from cufflinks) (5.11.0)
# Requirement already satisfied: six>=1.9.0 in c:\users\kbker\appdata\local\programs\python\python310\lib\site-packages (from cufflinks) (1.16.0)
# Requirement already satisfied: colorlover>=0.2.1 in c:\users\kbker\appdata\local\programs\python\python310\lib\site-packages (from cufflinks) (0.3.0)
# Requirement already satisfied: setuptools>=34.4.1 in c:\users\kbker\appdata\local\programs\python\python310\lib\site-packages (from cufflinks) (63.2.0)
# Requirement already satisfied: ipython>=5.3.0 in c:\users\kbker\appdata\local\programs\python\python310\lib\site-packages (from cufflinks) (8.5.0)
# Requirement already satisfied: ipywidgets>=7.0.0 in c:\users\kbker\appdata\local\programs\python\python310\lib\site-packages (from cufflinks) (8.0.3)
# Requirement already satisfied: matplotlib-inline in c:\users\kbker\appdata\local\programs\python\python310\lib\site-packages (from ipython>=5.3.0->cufflinks) (0.1.6)
# Requirement already satisfied: pickleshare in c:\users\kbker\appdata\local\programs\python\python310\lib\site-packages (from ipython>=5.3.0->cufflinks) (0.7.5)
# Requirement already satisfied: decorator in c:\users\kbker\appdata\local\programs\python\python310\lib\site-packages (from ipython>=5.3.0->cufflinks) (5.1.1)
# Requirement already satisfied: colorama in c:\users\kbker\appdata\local\programs\python\python310\lib\site-packages (from ipython>=5.3.0->cufflinks) (0.4.5)
# Requirement already satisfied: prompt-toolkit<3.1.0,>3.0.1 in c:\users\kbker\appdata\local\programs\python\python310\lib\site-packages (from ipython>=5.3.0->cufflinks) (3.0.31)
# Requirement already satisfied: traitlets>=5 in c:\users\kbker\appdata\local\programs\python\python310\lib\site-packages (from ipython>=5.3.0->cufflinks) (5.4.0)
# Requirement already satisfied: jedi>=0.16 in c:\users\kbker\appdata\local\programs\python\python310\lib\site-packages (from ipython>=5.3.0->cufflinks) (0.18.1)
# Requirement already satisfied: backcall in c:\users\kbker\appdata\local\programs\python\python310\lib\site-packages (from ipython>=5.3.0->cufflinks) (0.2.0)
# Requirement already satisfied: stack-data in c:\users\kbker\appdata\local\programs\python\python310\lib\site-packages (from ipython>=5.3.0->cufflinks) (0.5.0)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\kbker\appdata\local\programs\python\python310\lib\site-packages (from ipython>=5.3.0->cufflinks) (2.13.0)
# Requirement already satisfied: jupyterlab-widgets~=3.0 in c:\users\kbker\appdata\local\programs\python\python310\lib\site-packages (from ipywidgets>=7.0.0->cufflinks) (3.0.4)
# Requirement already satisfied: widgetsnbextension~=4.0 in c:\users\kbker\appdata\local\programs\python\python310\lib\site-packages (from ipywidgets>=7.0.0->cufflinks) (4.0.4)
# Requirement already satisfied: ipykernel>=4.5.1 in c:\users\kbker\appdata\local\programs\python\python310\lib\site-packages (from ipywidgets>=7.0.0->cufflinks) (6.15.3)
# Requirement already satisfied: pytz>=2020.1 in c:\users\kbker\appdata\local\programs\python\python310\lib\site-packages (from pandas>=0.19.2->cufflinks) (2022.6)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\kbker\appdata\local\programs\python\python310\lib\site-packages (from pandas>=0.19.2->cufflinks) (2.8.2)
# Requirement already satisfied: tenacity>=6.2.0 in c:\users\kbker\appdata\local\programs\python\python310\lib\site-packages (from plotly>=4.1.1->cufflinks) (8.1.0)
# Requirement already satisfied: tornado>=6.1 in c:\users\kbker\appdata\local\programs\python\python310\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->cufflinks) (6.2)
# Requirement already satisfied: psutil in c:\users\kbker\appdata\local\programs\python\python310\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->cufflinks) (5.9.2)
# Requirement already satisfied: jupyter-client>=6.1.12 in c:\users\kbker\appdata\local\programs\python\python310\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->cufflinks) (7.3.5)
# Requirement already satisfied: packaging in c:\users\kbker\appdata\local\programs\python\python310\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->cufflinks) (21.3)
# Requirement already satisfied: nest-asyncio in c:\users\kbker\appdata\local\programs\python\python310\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->cufflinks) (1.5.5)
# Requirement already satisfied: pyzmq>=17 in c:\users\kbker\appdata\local\programs\python\python310\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->cufflinks) (24.0.1)
# Requirement already satisfied: debugpy>=1.0 in c:\users\kbker\appdata\local\programs\python\python310\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->cufflinks) (1.6.3)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\users\kbker\appdata\local\programs\python\python310\lib\site-packages (from jedi>=0.16->ipython>=5.3.0->cufflinks) (0.8.3)
# Requirement already satisfied: wcwidth in c:\users\kbker\appdata\local\programs\python\python310\lib\site-packages (from prompt-toolkit<3.1.0,>3.0.1->ipython>=5.3.0->cufflinks) (0.2.5)
# Requirement already satisfied: pure-eval in c:\users\kbker\appdata\local\programs\python\python310\lib\site-packages (from stack-data->ipython>=5.3.0->cufflinks) (0.2.2)
# Requirement already satisfied: asttokens in c:\users\kbker\appdata\local\programs\python\python310\lib\site-packages (from stack-data->ipython>=5.3.0->cufflinks) (2.0.8)
# Requirement already satisfied: executing in c:\users\kbker\appdata\local\programs\python\python310\lib\site-packages (from stack-data->ipython>=5.3.0->cufflinks) (1.0.0)
# Requirement already satisfied: entrypoints in c:\users\kbker\appdata\local\programs\python\python310\lib\site-packages (from jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets>=7.0.0->cufflinks) (0.4)
# Requirement already satisfied: jupyter-core>=4.9.2 in c:\users\kbker\appdata\local\programs\python\python310\lib\site-packages (from jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets>=7.0.0->cufflinks) (4.11.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\kbker\appdata\local\programs\python\python310\lib\site-packages (from packaging->ipykernel>=4.5.1->ipywidgets>=7.0.0->cufflinks) (3.0.9)
# Requirement already satisfied: pywin32>=1.0 in c:\users\kbker\appdata\local\programs\python\python310\lib\site-packages (from jupyter-core>=4.9.2->jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets>=7.0.0->cufflinks) (304)
# Requirement already satisfied: missingno in c:\users\kbker\appdata\local\programs\python\python310\lib\site-packages (0.5.1)
# Requirement already satisfied: seaborn in c:\users\kbker\appdata\local\programs\python\python310\lib\site-packages (from missingno) (0.11.2)
# Requirement already satisfied: scipy in c:\users\kbker\appdata\local\programs\python\python310\lib\site-packages (from missingno) (1.9.3)
# Requirement already satisfied: numpy in c:\users\kbker\appdata\local\programs\python\python310\lib\site-packages (from missingno) (1.23.4)
# Requirement already satisfied: matplotlib in c:\users\kbker\appdata\local\programs\python\python310\lib\site-packages (from missingno) (3.6.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\kbker\appdata\local\programs\python\python310\lib\site-packages (from matplotlib->missingno) (2.8.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\kbker\appdata\local\programs\python\python310\lib\site-packages (from matplotlib->missingno) (1.4.4)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\kbker\appdata\local\programs\python\python310\lib\site-packages (from matplotlib->missingno) (4.38.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\kbker\appdata\local\programs\python\python310\lib\site-packages (from matplotlib->missingno) (21.3)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\kbker\appdata\local\programs\python\python310\lib\site-packages (from matplotlib->missingno) (1.0.6)
# Requirement already satisfied: cycler>=0.10 in c:\users\kbker\appdata\local\programs\python\python310\lib\site-packages (from matplotlib->missingno) (0.11.0)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\kbker\appdata\local\programs\python\python310\lib\site-packages (from matplotlib->missingno) (9.3.0)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\kbker\appdata\local\programs\python\python310\lib\site-packages (from matplotlib->missingno) (3.0.9)
# Requirement already satisfied: pandas>=0.23 in c:\users\kbker\appdata\local\programs\python\python310\lib\site-packages (from seaborn->missingno) (1.5.1)
# Requirement already satisfied: pytz>=2020.1 in c:\users\kbker\appdata\local\programs\python\python310\lib\site-packages (from pandas>=0.23->seaborn->missingno) (2022.6)
# Requirement already satisfied: six>=1.5 in c:\users\kbker\appdata\local\programs\python\python310\lib\site-packages (from python-dateutil>=2.7->matplotlib->missingno) (1.16.0)

# %%
from plotly.offline import init_notebook_mode, iplot, plot

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

#plotly
import plotly as py
init_notebook_mode(connected = True)
import plotly.graph_objs as go
import plotly.express as px

import warnings
warnings.filterwarnings("ignore")
warnings.warn("this will not show")

plt.rcParams["figure.figsize"] = (10, 6)

sns.set_style("whitegrid")
pd.set_option('display.float_format', lambda x: '%.3f' % x)

# Set it None to display all rows in the dataframe
# pd.set_option('display.max_rows', None)

# Set it to None to display all columns in the dataframe
pd.set_option('display.max_columns', None)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.16.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %% [markdown]
# ## <p style="background-color:#47AC34; font-family:newtimeroman; color:#FFF9ED; font-size:175%; text-align:center; border-radius:10px 10px;">Reading the data</p>

# %%
df = pd.read_csv("adult_eda.csv")
df.head(2)
# Out:
#    age         workclass  fnlwgt  education  education-num  \
# 0   39         State-gov   77516  Bachelors         13.000
# 1   50  Self-emp-not-inc   83311  Bachelors         13.000
#
#        marital-status       occupation   relationship   race   sex  \
# 0       Never-married     Adm-clerical  Not-in-family  White  Male
# 1  Married-civ-spouse  Exec-managerial        Husband  White  Male
#
#    capital-gain  capital-loss  hours-per-week native-country salary
# 0          2174             0              40  United-States  <=50K
# 1             0             0              13  United-States  <=50K

# %% [markdown]
# ## <p style="background-color:#47AC34; font-family:newtimeroman; color:#FFF9ED; font-size:175%; text-align:center; border-radius:10px 10px;">Recognizing and Understanding Data</p>
#
# <a id="3"></a>
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true"
# style="color:20b2aa; background-color:#47AC34" data-toggle="popover">Content</a>
#
# ### 1.Try to understand what the data looks like
# - Check the head, shape, data-types of the features.
# - Check if there are some dublicate rows or not. If there are, then drop them.
# - Check the statistical values of features.
# - If needed, rename the columns' names for easy use.
# - Basically check the missing values.

# %%
df.head()
# Out:
#    age         workclass  fnlwgt  education  education-num  \
# 0   39         State-gov   77516  Bachelors         13.000
# 1   50  Self-emp-not-inc   83311  Bachelors         13.000
# 2   38           Private  215646    HS-grad          9.000
# 3   53           Private  234721       11th          7.000
# 4   28           Private  338409  Bachelors         13.000
#
#        marital-status         occupation   relationship   race     sex  \
# 0       Never-married       Adm-clerical  Not-in-family  White    Male
# 1  Married-civ-spouse    Exec-managerial        Husband  White    Male
# 2            Divorced  Handlers-cleaners  Not-in-family  White    Male
# 3  Married-civ-spouse  Handlers-cleaners        Husband  Black    Male
# 4  Married-civ-spouse     Prof-specialty           Wife  Black  Female
#
#    capital-gain  capital-loss  hours-per-week native-country salary
# 0          2174             0              40  United-States  <=50K
# 1             0             0              13  United-States  <=50K
# 2             0             0              40  United-States  <=50K
# 3             0             0              40  United-States  <=50K
# 4             0             0              40           Cuba  <=50K

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/qFn8RZs/US-Citicens1.png)

# %%
df.shape
# Out:
# (32561, 15)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32561 entries, 0 to 32560
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             32561 non-null  int64
#  1   workclass       32561 non-null  object
#  2   fnlwgt          32561 non-null  int64
#  3   education       32561 non-null  object
#  4   education-num   31759 non-null  float64
#  5   marital-status  32561 non-null  object
#  6   occupation      32561 non-null  object
#  7   relationship    27493 non-null  object
#  8   race            32561 non-null  object
#  9   sex             32561 non-null  object
#  10  capital-gain    32561 non-null  int64
#  11  capital-loss    32561 non-null  int64
#  12  hours-per-week  32561 non-null  int64
#  13  native-country  32561 non-null  object
#  14  salary          32561 non-null  object
# dtypes: float64(1), int64(5), object(9)
# memory usage: 3.7+ MB

# %%
# Check if the Dataset have any Duplicate
df.duplicated().value_counts()
# Out:
# False    32537
# True        24
# dtype: int64

# %%
df.drop_duplicates(inplace=True)

# %%
df.shape
# Out:
# (32537, 15)

# %%
df.describe().T
# Out:
#                    count       mean        std       min        25%  \
# age            32537.000     38.586     13.638    17.000     28.000
# fnlwgt         32537.000 189780.849 105556.471 12285.000 117827.000
# education-num  31735.000     10.084      2.575     1.000      9.000
# capital-gain   32537.000   1078.444   7387.957     0.000      0.000
# capital-loss   32537.000     87.368    403.102     0.000      0.000
# hours-per-week 32537.000     40.440     12.347     1.000     40.000
#
#                       50%        75%         max
# age                37.000     48.000      90.000
# fnlwgt         178356.000 236993.000 1484705.000
# education-num      10.000     12.000      16.000
# capital-gain        0.000      0.000   99999.000
# capital-loss        0.000      0.000    4356.000
# hours-per-week     40.000     45.000      99.000

# %% [markdown]
# **Rename the features of;**<br>
# **``"education-num"``**, **``"marital-status"``**, **``"capital-gain"``**, **``"capital-loss"``**, **``"hours-per-week"``**, **``"native-country"``** **as**<br>
# **``"education_num"``**, **``"marital_status"``**, **``"capital_gain"``**, **``"capital_loss"``**, **``"hours_per_week"``**, **``"native_country"``**, **respectively and permanently.**

# %%
df.rename(columns={'education-num':'education_num', 'marital-status' : 'marital_status', 'capital-gain' : 'capital_gain',
'capital-loss' : 'capital_loss', 'hours-per-week' : 'hours_per_week', 'native-country' : 'native_country'}, inplace= True)
df.head()
# Out:
#    age         workclass  fnlwgt  education  education_num  \
# 0   39         State-gov   77516  Bachelors         13.000
# 1   50  Self-emp-not-inc   83311  Bachelors         13.000
# 2   38           Private  215646    HS-grad          9.000
# 3   53           Private  234721       11th          7.000
# 4   28           Private  338409  Bachelors         13.000
#
#        marital_status         occupation   relationship   race     sex  \
# 0       Never-married       Adm-clerical  Not-in-family  White    Male
# 1  Married-civ-spouse    Exec-managerial        Husband  White    Male
# 2            Divorced  Handlers-cleaners  Not-in-family  White    Male
# 3  Married-civ-spouse  Handlers-cleaners        Husband  Black    Male
# 4  Married-civ-spouse     Prof-specialty           Wife  Black  Female
#
#    capital_gain  capital_loss  hours_per_week native_country salary
# 0          2174             0              40  United-States  <=50K
# 1             0             0              13  United-States  <=50K
# 2             0             0              40  United-States  <=50K
# 3             0             0              40  United-States  <=50K
# 4             0             0              40           Cuba  <=50K

# %%
# Check the sum of Missing Values per column
df.isna().sum()
# Out:
# age                  0
# workclass            0
# fnlwgt               0
# education            0
# education_num      802
# marital_status       0
# occupation           0
# relationship      5064
# race                 0
# sex                  0
# capital_gain         0
# capital_loss         0
# hours_per_week       0
# native_country       0
# salary               0
# dtype: int64

# %%
# Check the Percentage of Missing Values
df.isna().sum() / df.shape[0] * 100
# Out:
# age               0.000
# workclass         0.000
# fnlwgt            0.000
# education         0.000
# education_num     2.465
# marital_status    0.000
# occupation        0.000
# relationship     15.564
# race              0.000
# sex               0.000
# capital_gain      0.000
# capital_loss      0.000
# hours_per_week    0.000
# native_country    0.000
# salary            0.000
# dtype: float64

# %% [markdown]
# ### 2.Look at the value counts of columns that have object datatype and detect strange values apart from the NaN Values

# %%
df.columns
# Out:
# Index(['age', 'workclass', 'fnlwgt', 'education', 'education_num',
#        'marital_status', 'occupation', 'relationship', 'race', 'sex',
#        'capital_gain', 'capital_loss', 'hours_per_week', 'native_country',
#        'salary'],
#       dtype='object')

# %% [markdown]
# **Assign the Columns (Features) of object data type as** **``"object_col"``**

# %%
object_cols = df.select_dtypes(include = 'object')
object_cols
# Out:
#               workclass   education      marital_status         occupation  \
# 0             State-gov   Bachelors       Never-married       Adm-clerical
# 1      Self-emp-not-inc   Bachelors  Married-civ-spouse    Exec-managerial
# 2               Private     HS-grad            Divorced  Handlers-cleaners
# 3               Private        11th  Married-civ-spouse  Handlers-cleaners
# 4               Private   Bachelors  Married-civ-spouse     Prof-specialty
# ...                 ...         ...                 ...                ...
# 32556           Private  Assoc-acdm  Married-civ-spouse       Tech-support
# 32557           Private     HS-grad  Married-civ-spouse  Machine-op-inspct
# 32558           Private     HS-grad             Widowed       Adm-clerical
# 32559           Private     HS-grad       Never-married       Adm-clerical
# 32560      Self-emp-inc     HS-grad  Married-civ-spouse    Exec-managerial
#
#         relationship   race     sex native_country salary
# 0      Not-in-family  White    Male  United-States  <=50K
# 1            Husband  White    Male  United-States  <=50K
# 2      Not-in-family  White    Male  United-States  <=50K
# 3            Husband  Black    Male  United-States  <=50K
# 4               Wife  Black  Female           Cuba  <=50K
# ...              ...    ...     ...            ...    ...
# 32556           Wife  White  Female  United-States  <=50K
# 32557        Husband  White    Male  United-States   >50K
# 32558      Unmarried  White  Female  United-States  <=50K
# 32559            NaN  White    Male  United-States  <=50K
# 32560           Wife  White  Female  United-States   >50K
#
# [32537 rows x 9 columns]

# %%
for col in object_cols:
    print(col)
    print("--"*8)
    print(df[col].value_counts(dropna=False))
    print("--"*20)
# Out:
# workclass
# ----------------
# Private             22673
# Self-emp-not-inc     2540
# Local-gov            2093
# ?                    1836
# State-gov            1298
# Self-emp-inc         1116
# Federal-gov           960
# Without-pay            14
# Never-worked            7
# Name: workclass, dtype: int64
# ----------------------------------------
# education
# ----------------
# HS-grad         10494
# Some-college     7282
# Bachelors        5353
# Masters          1722
# Assoc-voc        1382
# 11th             1175
# Assoc-acdm       1067
# 10th              933
# 7th-8th           645
# Prof-school       576
# 9th               514
# 12th              433
# Doctorate         413
# 5th-6th           332
# 1st-4th           166
# Preschool          50
# Name: education, dtype: int64
# ----------------------------------------
# marital_status
# ----------------
# Married-civ-spouse       14970
# Never-married            10667
# Divorced                  4441
# Separated                 1025
# Widowed                    993
# Married-spouse-absent      418
# Married-AF-spouse           23
# Name: marital_status, dtype: int64
# ----------------------------------------
# occupation
# ----------------
# Prof-specialty       4136
# Craft-repair         4094
# Exec-managerial      4065
# Adm-clerical         3768
# Sales                3650
# Other-service        3291
# Machine-op-inspct    2000
# ?                    1843
# Transport-moving     1597
# Handlers-cleaners    1369
# Farming-fishing       992
# Tech-support          927
# Protective-serv       649
# Priv-house-serv       147
# Armed-Forces            9
# Name: occupation, dtype: int64
# ----------------------------------------
# relationship
# ----------------
# Husband           13187
# Not-in-family      8292
# NaN                5064
# Unmarried          3445
# Wife               1568
# Other-relative      981
# Name: relationship, dtype: int64
# ----------------------------------------
# race
# ----------------
# White                 27795
# Black                  3122
# Asian-Pac-Islander     1038
# Amer-Indian-Eskimo      311
# Other                   271
# Name: race, dtype: int64
# ----------------------------------------
# sex
# ----------------
# Male      21775
# Female    10762
# Name: sex, dtype: int64
# ----------------------------------------
# native_country
# ----------------
# United-States                 29153
# Mexico                          639
# ?                               582
# Philippines                     198
# Germany                         137
# Canada                          121
# Puerto-Rico                     114
# El-Salvador                     106
# India                           100
# Cuba                             95
# England                          90
# Jamaica                          81
# South                            80
# China                            75
# Italy                            73
# Dominican-Republic               70
# Vietnam                          67
# Japan                            62
# Guatemala                        62
# Poland                           60
# Columbia                         59
# Taiwan                           51
# Haiti                            44
# Iran                             43
# Portugal                         37
# Nicaragua                        34
# Peru                             31
# France                           29
# Greece                           29
# Ecuador                          28
# Ireland                          24
# Hong                             20
# Cambodia                         19
# Trinadad&Tobago                  19
# Laos                             18
# Thailand                         18
# Yugoslavia                       16
# Outlying-US(Guam-USVI-etc)       14
# Honduras                         13
# Hungary                          13
# Scotland                         12
# Holand-Netherlands                1
# Name: native_country, dtype: int64
# ----------------------------------------
# salary
# ----------------
# <=50K    24698
# >50K      7839
# Name: salary, dtype: int64
# ----------------------------------------

# %% [markdown]
# **Check if the Dataset has any Question Mark** **``"?"``**

# %%
 df['age'] == '?'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In [101], line 1
# ----> 1 df['age'] == '?'.count()
#
# TypeError: count() takes at least 1 argument (0 given)

# %%
df.isin(['?'])
# Out:
#          age  workclass  fnlwgt  education  education_num  marital_status  \
# 0      False      False   False      False          False           False
# 1      False      False   False      False          False           False
# 2      False      False   False      False          False           False
# 3      False      False   False      False          False           False
# 4      False      False   False      False          False           False
# ...      ...        ...     ...        ...            ...             ...
# 32556  False      False   False      False          False           False
# 32557  False      False   False      False          False           False
# 32558  False      False   False      False          False           False
# 32559  False      False   False      False          False           False
# 32560  False      False   False      False          False           False
#
#        occupation  relationship   race    sex  capital_gain  capital_loss  \
# 0           False         False  False  False         False         False
# 1           False         False  False  False         False         False
# 2           False         False  False  False         False         False
# 3           False         False  False  False         False         False
# 4           False         False  False  False         False         False
# ...           ...           ...    ...    ...           ...           ...
# 32556       False         False  False  False         False         False
# 32557       False         False  False  False         False         False
# 32558       False         False  False  False         False         False
# 32559       False         False  False  False         False         False
# 32560       False         False  False  False         False         False
#
#        hours_per_week  native_country  salary
# 0               False           False   False
# 1               False           False   False
# 2               False           False   False
# 3               False           False   False
# 4               False           False   False
# ...               ...             ...     ...
# 32556           False           False   False
# 32557           False           False   False
# 32558           False           False   False
# 32559           False           False   False
# 32560           False           False   False
#
# [32537 rows x 15 columns]

# %%
df.isin(['?']).sum()
# Out:
# age                  0
# workclass         1836
# fnlwgt               0
# education            0
# education_num        0
# marital_status       0
# occupation        1843
# relationship         0
# race                 0
# sex                  0
# capital_gain         0
# capital_loss         0
# hours_per_week       0
# native_country     582
# salary               0
# dtype: int64

# %% [markdown]
# ## <p style="background-color:#47AC34; font-family:newtimeroman; color:#FFF9ED; font-size:175%; text-align:center; border-radius:10px 10px;">Univariate & Multivariate Analysis</p>
#
# <a id="4"></a>
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true"
# style="color:20b2aa; background-color:#47AC34" data-toggle="popover">Content</a>
#
# Examine all features (first target feature("salary"), then numeric ones, lastly categoric ones) separetly from different aspects according to target feature.
#
# **to do list for numeric features:**
# 1. Check the boxplot to see extreme values
# 2. Check the histplot/kdeplot to see distribution of feature
# 3. Check the statistical values
# 4. Check the boxplot and histplot/kdeplot by "salary" levels
# 5. Check the statistical values by "salary" levels
# 6. Write down the conclusions you draw from your analysis
#
# **to do list for categoric features:**
# 1. Find the features which contains similar values, examine the similarities and analyze them together
# 2. Check the count/percentage of person in each categories and visualize it with a suitable plot
# 3. If need, decrease the number of categories by combining similar categories
# 4. Check the count of person in each "salary" levels by categories and visualize it with a suitable plot
# 5. Check the percentage distribution of person in each "salary" levels by categories and visualize it with suitable plot
# 6. Check the count of person in each categories by "salary" levels and visualize it with a suitable plot
# 7. Check the percentage distribution of person in each categories by "salary" levels and visualize it with suitable plot
# 8. Write down the conclusions you draw from your analysis
#
# **Note :** Instruction/direction for each feature is available under the corresponding feature in detail, as well.

# %% [markdown]
# ## Salary (Target Feature)

# %% [markdown]
# **Check the count of person in each "salary" levels and visualize it with a countplot**

# %%
df.salary.value_counts()
# Out:
# <=50K    24698
# >50K      7839
# Name: salary, dtype: int64

# %%
fig, ax = plt.subplots()
ax = sns.countplot(df["salary"])
for p in ax.patches:
    ax.annotate((p.get_height()), (p.get_x() + 0.3, p.get_height() + 0.5));

# %% [markdown]
# **Check the percentage of person in each "salary" levels and visualize it with a pieplot**

# %%
percentage = df.salary.value_counts() / df.shape[0]
percentage
# Out:
# <=50K   0.759
# >50K    0.241
# Name: salary, dtype: float64

# %%
yvalue = percentage.values
yvalue
# Out:
# array([0.75907428, 0.24092572])

# %%
xvalue = percentage.index
xvalue
# Out:
# Index(['<=50K', '>50K'], dtype='object')

# %%
plt.figure(figsize = (10,6))

color_list = ["blue", "yellow"]

explode_list = [0, 0.1]

plt.pie(yvalue, labels = xvalue, labeldistance = 0.7, autopct = "%.1f", shadow=True, pctdistance=0.6,
       colors = color_list, explode = explode_list );

# %% [markdown]
# **Write down the conclusions you draw from your analysis**

# %% [markdown]
# **Result :** %75.9 of people work for <=50K,
#              %24.1 of people work for >50K

# %% [markdown]
# ## Numeric Features

# %% [markdown]
# ## age

# %% [markdown]
# **Check the boxplot to see extreme values**

# %%
plt.figure(figsize = (10,5))

sns.boxplot(x = 'age', data = df);

# %% [markdown]
# **Check the histplot/kdeplot to see distribution of feature**

# %%
plt.figure(figsize = (10, 5))
sns.histplot(data = df, x = "age", bins = 30, kde= True);

# %% [markdown]
# **Check the statistical values**

# %%
df.describe().T.loc['age']
# Out:
# count   32537.000
# mean       38.586
# std        13.638
# min        17.000
# 25%        28.000
# 50%        37.000
# 75%        48.000
# max        90.000
# Name: age, dtype: float64

# %% [markdown]
# **Check the boxplot and histplot/kdeplot by "salary" levels**

# %%
sns.boxplot(x = "salary", y = 'age', data = df);

# %%
sns.histplot(data = df, x = "age", hue= 'salary', bins=20, kde  = True);

# %%
sns.kdeplot(data = df, x = "age", hue = "salary", shade = True);

# %% [markdown]
# **Check the statistical values by "salary" levels**

# %%
df.describe().T ## bakilacak
# Out:
#                    count       mean        std       min        25%  \
# age            32537.000     38.586     13.638    17.000     28.000
# fnlwgt         32537.000 189780.849 105556.471 12285.000 117827.000
# education_num  31735.000     10.084      2.575     1.000      9.000
# capital_gain   32537.000   1078.444   7387.957     0.000      0.000
# capital_loss   32537.000     87.368    403.102     0.000      0.000
# hours_per_week 32537.000     40.440     12.347     1.000     40.000
#
#                       50%        75%         max
# age                37.000     48.000      90.000
# fnlwgt         178356.000 236993.000 1484705.000
# education_num      10.000     12.000      16.000
# capital_gain        0.000      0.000   99999.000
# capital_loss        0.000      0.000    4356.000
# hours_per_week     40.000     45.000      99.000

# %%
df['age'].describe()
# Out:
# count   32537.000
# mean       38.586
# std        13.638
# min        17.000
# 25%        28.000
# 50%        37.000
# 75%        48.000
# max        90.000
# Name: age, dtype: float64

# %% [markdown]
# **Write down the conclusions you draw from your analysis**

# %% [markdown]
# **Result :** The mean and median age of the high-income group is higher than the low-income group. It means the older generation possesses more wealth than the young.

# %% [markdown]
# ## fnlwgt

# %% [markdown]
# **Check the boxplot to see extreme values**

# %%
plt.figure(figsize = (10,5))

sns.boxplot(x = 'fnlwgt', data = df);

# %% [markdown]
# **Check the histplot/kdeplot to see distribution of feature**

# %%
sns.kdeplot(data = df, x = "fnlwgt", shade = True);

# %% [markdown]
# **Check the statistical values**

# %%
df.describe().T.loc['fnlwgt']
# Out:
# count     32537.000
# mean     189780.849
# std      105556.471
# min       12285.000
# 25%      117827.000
# 50%      178356.000
# 75%      236993.000
# max     1484705.000
# Name: fnlwgt, dtype: float64

# %% [markdown]
# **Check the boxplot and histplot/kdeplot by "salary" levels**

# %%
sns.boxplot(x = "salary", y = 'fnlwgt', data = df);

# %%
sns.kdeplot(data = df, x = "fnlwgt", hue = "salary", shade = True);

# %% [markdown]
# **Check the statistical values by "salary" levels**

# %% [markdown]
# **Write down the conclusions you draw from your analysis**

# %% [markdown]
# **Result :** There is no significant difference between high and low-income groups according to the "fnlwgt" feature.

# %% [markdown]
# ## capital_gain

# %% [markdown]
# **Check the boxplot to see extreme values**

# %%
plt.figure(figsize = (10,5))

sns.boxplot(x = 'capital_gain', data = df);

# %% [markdown]
# **Check the histplot/kdeplot to see distribution of feature**

# %%
sns.kdeplot(data = df, x = "capital_gain", shade = True);

# %% [markdown]
# **Check the statistical values**

# %%
df.describe().T.loc['capital_gain']
# Out:
# count   32537.000
# mean     1078.444
# std      7387.957
# min         0.000
# 25%         0.000
# 50%         0.000
# 75%         0.000
# max     99999.000
# Name: capital_gain, dtype: float64

# %% [markdown]
# **Check the boxplot and histplot/kdeplot by "salary" levels**

# %%
plt.figure(figsize = (10,5))

sns.boxplot(x = 'salary', y= 'capital_gain', data = df);

# %%
sns.kdeplot(data = df, x = "capital_gain", hue= 'salary', shade = True);

# %% [markdown]
# **Check the statistical values by "salary" levels**

# %% [markdown]
# **Check the statistical values by "salary" levels for capital_gain not equal the zero**

# %% [markdown]
# **Write down the conclusions you draw from your analysis**

# %% [markdown]
# **Result :** The "capital-gain" feature has not provided very meaningful insights. Nevertheless, we can say that the more "capital-gain", the more "high-income".

# %% [markdown]
# ## capital_loss

# %% [markdown]
# **Check the boxplot to see extreme values**

# %%
plt.figure(figsize = (10,5))

sns.boxplot( x= 'capital_loss', data = df);

# %% [markdown]
# **Check the histplot/kdeplot to see distribution of feature**

# %%
sns.kdeplot(data = df, x = "capital_loss", shade = True);

# %% [markdown]
# **Check the statistical values**

# %%
df.describe().T.loc['capital_loss']
# Out:
# count   32537.000
# mean       87.368
# std       403.102
# min         0.000
# 25%         0.000
# 50%         0.000
# 75%         0.000
# max      4356.000
# Name: capital_loss, dtype: float64

# %% [markdown]
# **Check the boxplot and histplot/kdeplot by "salary" levels**

# %%
plt.figure(figsize = (10,5))

sns.boxplot( x= 'salary', y= 'capital_loss', data = df);

# %%
sns.kdeplot(data = df, x = "capital_loss", hue = 'salary', shade = True);

# %% [markdown]
# **Check the statistical values by "salary" levels**

# %% [markdown]
# **Check the statistical values by "salary" levels for capital_loss not equel the zero**

# %% [markdown]
# **Write down the conclusions you draw from your analysis**

# %% [markdown]
# **Result :** There is no significant difference between high and low-income groups according to the "capital_loss" feature.

# %% [markdown]
# ## hours_per_week

# %% [markdown]
# **Check the boxplot to see extreme values**

# %%
sns.boxplot(x = "hours_per_week", data = df);

# %% [markdown]
# **Check the histplot/kdeplot to see distribution of feature**

# %%
sns.kdeplot(data = df, x='hours_per_week', shade=True)
# Out:
# <AxesSubplot: xlabel='hours_per_week', ylabel='Density'>

# %% [markdown]
# **Check the statistical values**

# %%
df.describe().T.loc['hours_per_week']
# Out:
# count   32537.000
# mean       40.440
# std        12.347
# min         1.000
# 25%        40.000
# 50%        40.000
# 75%        45.000
# max        99.000
# Name: hours_per_week, dtype: float64

# %% [markdown]
# **Check the boxplot and histplot/kdeplot by "salary" levels**

# %%
sns.boxplot(x = "salary", y = 'hours_per_week', data = df);

# %%
sns.kdeplot(data = df, x='hours_per_week', hue = 'salary', shade=True);

# %% [markdown]
# **Check the statistical values by "salary" levels**

# %% [markdown]
# **Write down the conclusions you draw from your analysis**

# %% [markdown]
# **Result :** To be in a high-income group, almost at least 40 hours working per week is required. Most of those who work less than 40 hours per week are in the low-income group.

# %% [markdown]
# ### See the relationship between each numeric features by target feature (salary) in one plot basically

# %%
sns.pairplot(data = df, hue = "salary", palette = 'viridis', corner = True);

# %% [markdown]
# ## Categorical Features

# %% [markdown]
# ## education & education_num

# %% [markdown]
# **Detect the similarities between these features by comparing unique values**

# %%
df.education.value_counts(dropna = False)
# Out:
# HS-grad         10494
# Some-college     7282
# Bachelors        5353
# Masters          1722
# Assoc-voc        1382
# 11th             1175
# Assoc-acdm       1067
# 10th              933
# 7th-8th           645
# Prof-school       576
# 9th               514
# 12th              433
# Doctorate         413
# 5th-6th           332
# 1st-4th           166
# Preschool          50
# Name: education, dtype: int64

# %%
df.education_num.value_counts(dropna = False)
# Out:
# 9.000     10208
# 10.000     7089
# 13.000     5245
# 14.000     1686
# 11.000     1343
# 7.000      1146
# 12.000     1044
# 6.000       916
# NaN         802
# 4.000       630
# 15.000      559
# 5.000       503
# 8.000       424
# 16.000      405
# 3.000       329
# 2.000       159
# 1.000        49
# Name: education_num, dtype: int64

# %%
df.groupby('education')['education_num'].value_counts(dropna = False)
# Out:
# education     education_num
# 10th          6.000              916
#               NaN                 17
# 11th          7.000             1146
#               NaN                 29
# 12th          8.000              424
#               NaN                  9
# 1st-4th       2.000              159
#               NaN                  7
# 5th-6th       3.000              329
#               NaN                  3
# 7th-8th       4.000              630
#               NaN                 15
# 9th           5.000              503
#               NaN                 11
# Assoc-acdm    12.000            1044
#               NaN                 23
# Assoc-voc     11.000            1343
#               NaN                 39
# Bachelors     13.000            5245
#               NaN                108
# Doctorate     16.000             405
#               NaN                  8
# HS-grad       9.000            10208
#               NaN                286
# Masters       14.000            1686
#               NaN                 36
# Preschool     1.000               49
#               NaN                  1
# Prof-school   15.000             559
#               NaN                 17
# Some-college  10.000            7089
#               NaN                193
# Name: education_num, dtype: int64

# %% [markdown]
# **Visualize the count of person in each categories for these features (education, education_num) separately**

# %%
school = df.education.value_counts()
school.index = school.index


fig, ax = plt.subplots(figsize = (10, 6))

sns.countplot(data = df, x = 'education')
ax.set_xticklabels(school.index, rotation = 90)


plt.tight_layout()

# %%
sns.countplot(data = df, x = 'education_num');

# %% [markdown]
# **Check the count of person in each "salary" levels by these features (education and education_num) separately and visualize them with countplot**

# %%
df.groupby('education')['salary'].value_counts(dropna = False)
# Out:
# education     salary
# 10th          <=50K      871
#               >50K        62
# 11th          <=50K     1115
#               >50K        60
# 12th          <=50K      400
#               >50K        33
# 1st-4th       <=50K      160
#               >50K         6
# 5th-6th       <=50K      316
#               >50K        16
# 7th-8th       <=50K      605
#               >50K        40
# 9th           <=50K      487
#               >50K        27
# Assoc-acdm    <=50K      802
#               >50K       265
# Assoc-voc     <=50K     1021
#               >50K       361
# Bachelors     <=50K     3132
#               >50K      2221
# Doctorate     >50K       306
#               <=50K      107
# HS-grad       <=50K     8820
#               >50K      1674
# Masters       >50K       959
#               <=50K      763
# Preschool     <=50K       50
# Prof-school   >50K       423
#               <=50K      153
# Some-college  <=50K     5896
#               >50K      1386
# Name: salary, dtype: int64

# %%
fig, ax = plt.subplots(figsize = (6, 5))

sns.countplot(data = df, x = 'education', hue= 'salary')
ax.set_xticklabels(school.index, rotation = 90)


plt.tight_layout()

# %%
df.groupby('education_num')['salary'].value_counts(dropna = False)
# Out:
# education_num  salary
# 1.000          <=50K       49
# 2.000          <=50K      153
#                >50K         6
# 3.000          <=50K      313
#                >50K        16
# 4.000          <=50K      592
#                >50K        38
# 5.000          <=50K      477
#                >50K        26
# 6.000          <=50K      854
#                >50K        62
# 7.000          <=50K     1088
#                >50K        58
# 8.000          <=50K      391
#                >50K        33
# 9.000          <=50K     8579
#                >50K      1629
# 10.000         <=50K     5746
#                >50K      1343
# 11.000         <=50K      994
#                >50K       349
# 12.000         <=50K      787
#                >50K       257
# 13.000         <=50K     3078
#                >50K      2167
# 14.000         >50K       935
#                <=50K      751
# 15.000         >50K       410
#                <=50K      149
# 16.000         >50K       302
#                <=50K      103
# Name: salary, dtype: int64

# %%
sns.countplot(data = df, x = "education_num", hue = 'salary');

# %% [markdown]
# **Visualize the boxplot of "education_num" feature by "salary" levels**

# %%
sns.boxplot(x = "salary", y = 'education_num', data = df);

# %% [markdown]
# **Decrease the number of categories in "education" feature as low, medium, and high level and create a new feature with this new categorical data.**

# %%
def mapping_education(x):
    if x in ["Preschool", "1st-4th", "5th-6th", "7th-8th", "9th", "10th", "11th", "12th"]:
        return "low_level_grade"
    elif x in ["HS-grad", "Some-college", "Assoc-voc", "Assoc-acdm"]:
        return "medium_level_grade"
    elif x in ["Bachelors", "Masters", "Prof-school", "Doctorate"]:
        return "high_level_grade"

# %% [markdown]
# **Visualize the count of person in each categories for these new education levels (high, medium, low)**

# %% [markdown]
# **Check the count of person in each "salary" levels by these new education levels(high, medium, low) and visualize it with countplot**

# %% [markdown]
# **Check the percentage distribution of person in each "salary" levels by each new education levels (high, medium, low) and visualize it with pie plot separately**

# %% [markdown]
# **Check the count of person in each these new education levels(high, medium, low) by "salary" levels and visualize it with countplot**

# %% [markdown]
# **Check the the percentage distribution of person in each these new education levels(high, medium, low) by "salary" levels and visualize it with pie plot separately**

# %% [markdown]
# **Write down the conclusions you draw from your analysis**

# %% [markdown]
# **Result :** We can easily say that the more education the more high income.

# %% [markdown]
# ## marital_status & relationship

# %% [markdown]
# **Detect the similarities between these features by comparing unique values**

# %%
df.marital_status.value_counts(dropna = False)
# Out:
# Married-civ-spouse       14970
# Never-married            10667
# Divorced                  4441
# Separated                 1025
# Widowed                    993
# Married-spouse-absent      418
# Married-AF-spouse           23
# Name: marital_status, dtype: int64

# %%
df.relationship.value_counts(dropna = False)
# Out:
# Husband           13187
# Not-in-family      8292
# NaN                5064
# Unmarried          3445
# Wife               1568
# Other-relative      981
# Name: relationship, dtype: int64

# %%
df['relationship'] = df['relationship'].replace(np.nan , 'Unknown')

# %%
df.relationship.value_counts(dropna = False)
# Out:
# Husband           13187
# Not-in-family      8292
# Unknown            5064
# Unmarried          3445
# Wife               1568
# Other-relative      981
# Name: relationship, dtype: int64

# %%
df.groupby('relationship')['marital_status'].value_counts(dropna = False)
# Out:
# relationship    marital_status
# Husband         Married-civ-spouse       13178
#                 Married-AF-spouse            9
# Not-in-family   Never-married             4694
#                 Divorced                  2403
#                 Widowed                    547
#                 Separated                  420
#                 Married-spouse-absent      211
#                 Married-civ-spouse          17
# Other-relative  Never-married              611
#                 Married-civ-spouse         124
#                 Divorced                   110
#                 Separated                   55
#                 Widowed                     48
#                 Married-spouse-absent       32
#                 Married-AF-spouse            1
# Unknown         Never-married             4481
#                 Divorced                   328
#                 Separated                   99
#                 Married-civ-spouse          95
#                 Married-spouse-absent       45
#                 Widowed                     15
#                 Married-AF-spouse            1
# Unmarried       Divorced                  1600
#                 Never-married              881
#                 Separated                  451
#                 Widowed                    383
#                 Married-spouse-absent      130
# Wife            Married-civ-spouse        1556
#                 Married-AF-spouse           12
# Name: marital_status, dtype: int64

# %% [markdown]
# **Assessment :** Unmarried people were classified into different subcategories. ........

# %% [markdown]
# **Visualize the count of person in each categories**

# %%
df['marital_status'].value_counts()
# Out:
# Married-civ-spouse       14970
# Never-married            10667
# Divorced                  4441
# Separated                 1025
# Widowed                    993
# Married-spouse-absent      418
# Married-AF-spouse           23
# Name: marital_status, dtype: int64

# %%
marital_status = df.marital_status.value_counts()
marital_status.index

fig, ax = plt.subplots(figsize = (6, 5))

sns.countplot(data = df, x = 'marital_status')
ax.set_xticklabels(marital_status.index, rotation = 45)
plt.tight_layout()

# %% [markdown]
# **Check the count of person in each "salary" levels by categories and visualize it with countplot**

# %%
df.groupby('marital_status')['salary'].value_counts(dropna = False)
# Out:
# marital_status         salary
# Divorced               <=50K      3978
#                        >50K        463
# Married-AF-spouse      <=50K        13
#                        >50K         10
# Married-civ-spouse     <=50K      8280
#                        >50K       6690
# Married-spouse-absent  <=50K       384
#                        >50K         34
# Never-married          <=50K     10176
#                        >50K        491
# Separated              <=50K       959
#                        >50K         66
# Widowed                <=50K       908
#                        >50K         85
# Name: salary, dtype: int64

# %%
marital_status = df.marital_status.value_counts()
marital_status.index

fig, ax = plt.subplots(figsize = (6, 5))

sns.countplot(data = df, x = 'marital_status', hue = 'salary')
ax.set_xticklabels(marital_status.index, rotation = 45)
plt.tight_layout()

# %% [markdown]
# **Decrease the number of categories in "marital_status" feature as married, and unmarried and create a new feature with this new categorical data**

# %% [markdown]
# **Visualize the count of person in each categories for these new marital status (married, unmarried)**

# %% [markdown]
# **Check the count of person in each "salary" levels by these new marital status (married, unmarried) and visualize it with countplot**

# %% [markdown]
# **Check the percentage distribution of person in each "salary" levels by each new marital status (married, unmarried) and visualize it with pie plot separately**

# %% [markdown]
# **Check the count of person in each these new marital status (married, unmarried) by "salary" levels and visualize it with countplot**

# %% [markdown]
# **Check the the percentage distribution of person in each these new marital status (married, unmarried) by "salary" levels and visualize it with pie plot separately**

# %% [markdown]
# **Write down the conclusions you draw from your analysis**

# %% [markdown]
# **Result :** We can easily say that married persons have earned more income than unmarried persons.

# %% [markdown]
# ## workclass

# %% [markdown]
# **Check the count of person in each categories and visualize it with countplot**

# %%
df.workclass.value_counts()
# Out:
# Private             22696
# Self-emp-not-inc     2541
# Local-gov            2093
# ?                    1836
# State-gov            1298
# Self-emp-inc         1116
# Federal-gov           960
# Without-pay            14
# Never-worked            7
# Name: workclass, dtype: int64

# %%
workclass = df.workclass.value_counts()
workclass.index

fig, ax = plt.subplots(figsize = (6, 5))

sns.countplot(data = df, x = 'workclass')
ax.set_xticklabels(workclass.index, rotation = 90)
plt.tight_layout()

# %% [markdown]
# **Replace the value "?" to the value "Unknown"**

# %%
# Replace "?" values with "Unkown"
df['workclass'] = df['workclass'].replace('?', 'Unknown')

# %% [markdown]
# **Check the count of person in each "salary" levels by workclass groups and visualize it with countplot**

# %%
df.groupby('workclass')['salary'].value_counts(dropna = False)
# Out:
# workclass         salary
# Federal-gov       <=50K       589
#                   >50K        371
# Local-gov         <=50K      1476
#                   >50K        617
# Never-worked      <=50K         7
# Private           <=50K     17712
#                   >50K       4961
# Self-emp-inc      >50K        622
#                   <=50K       494
# Self-emp-not-inc  <=50K      1816
#                   >50K        724
# State-gov         <=50K       945
#                   >50K        353
# Unknown           <=50K      1645
#                   >50K        191
# Without-pay       <=50K        14
# Name: salary, dtype: int64

# %%
workclass = df.workclass.value_counts()
workclass.index
# Out:
# Index(['Private', 'Self-emp-not-inc', 'Local-gov', 'Unknown', 'State-gov',
#        'Self-emp-inc', 'Federal-gov', 'Without-pay', 'Never-worked'],
#       dtype='object')

# %%
fig, ax = plt.subplots(figsize= (7, 6))

ax = sns.countplot(x = "city", data = kill, order= xvalue)

ax.set_xticklabels(city.index, rotation = 45)


plt.tight_layout()

# %%
sns.countplot(data = df, x = 'workclass', hue= 'salary');

# %% [markdown]
# **Check the percentage distribution of person in each "salary" levels by each workclass groups and visualize it with bar plot**

# %%
df.groupby('workclass')['salary'].value_counts(dropna = False) /
# Out:
# workclass         salary
# Federal-gov       <=50K       589
#                   >50K        371
# Local-gov         <=50K      1476
#                   >50K        617
# Never-worked      <=50K         7
# Private           <=50K     17733
#                   >50K       4963
# Self-emp-inc      >50K        622
#                   <=50K       494
# Self-emp-not-inc  <=50K      1817
#                   >50K        724
# State-gov         <=50K       945
#                   >50K        353
# Unknown           <=50K      1645
#                   >50K        191
# Without-pay       <=50K        14
# Name: salary, dtype: int64

# %%
df.groupby('workclass')['salary'].value_counts(dropna = False)
# Out:
# workclass         salary
# Federal-gov       <=50K       589
#                   >50K        371
# Local-gov         <=50K      1476
#                   >50K        617
# Never-worked      <=50K         7
# Private           <=50K     17712
#                   >50K       4961
# Self-emp-inc      >50K        622
#                   <=50K       494
# Self-emp-not-inc  <=50K      1816
#                   >50K        724
# State-gov         <=50K       945
#                   >50K        353
# Unknown           <=50K      1645
#                   >50K        191
# Without-pay       <=50K        14
# Name: salary, dtype: int64

# %%
df.groupby('workclass')['salary'].value_counts(dropna = False)
# Out:
# workclass         salary
# Federal-gov       <=50K       589
#                   >50K        371
# Local-gov         <=50K      1476
#                   >50K        617
# Never-worked      <=50K         7
# Private           <=50K     17712
#                   >50K       4961
# Self-emp-inc      >50K        622
#                   <=50K       494
# Self-emp-not-inc  <=50K      1816
#                   >50K        724
# State-gov         <=50K       945
#                   >50K        353
# Unknown           <=50K      1645
#                   >50K        191
# Without-pay       <=50K        14
# Name: salary, dtype: int64

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/8YvM14M/57.png)

# %% [markdown]
# **Check the count of person in each workclass groups by "salary" levels and visualize it with countplot**

# %%
df.groupby('salary')['workclass'].value_counts(dropna = False)
# Out:
# salary  workclass
# <=50K   Private             17733
#         Self-emp-not-inc     1817
#         Unknown              1645
#         Local-gov            1476
#         State-gov             945
#         Federal-gov           589
#         Self-emp-inc          494
#         Without-pay            14
#         Never-worked            7
# >50K    Private              4963
#         Self-emp-not-inc      724
#         Self-emp-inc          622
#         Local-gov             617
#         Federal-gov           371
#         State-gov             353
#         Unknown               191
# Name: workclass, dtype: int64

# %%
sns.countplot(data = df, x = 'salary', hue = 'workclass' );

# %% [markdown]
# **Check the the percentage distribution of person in each workclass groups by "salary" levels and visualize it with countplot**

# %% [markdown]
# **Write down the conclusions you draw from your analysis**

# %% [markdown]
# **Result :** "Self-emp-inc" work-class has a high ratio in the self group about high-level income. "Private" work-class has a high ratio in the high-income group about high-level income.

# %% [markdown]
# ## occupation

# %% [markdown]
# **Check the count of person in each categories and visualize it with countplot**

# %%
df.occupation.value_counts()
# Out:
# Prof-specialty       4136
# Craft-repair         4094
# Exec-managerial      4065
# Adm-clerical         3768
# Sales                3650
# Other-service        3291
# Machine-op-inspct    2000
# ?                    1843
# Transport-moving     1597
# Handlers-cleaners    1369
# Farming-fishing       992
# Tech-support          927
# Protective-serv       649
# Priv-house-serv       147
# Armed-Forces            9
# Name: occupation, dtype: int64

# %%
sns.countplot(data = df, x = "occupation" );

# %% [markdown]
# **Replace the value "?" to the value "Unknown"**

# %%
df['occupation'] = df['occupation'].replace('?', 'Unknown')

# %% [markdown]
# **Check the count of person in each "salary" levels by occupation groups and visualize it with countplot**

# %%
df.groupby('occupation')['salary'].value_counts(dropna = False)
# Out:
# occupation         salary
# Adm-clerical       <=50K     3261
#                    >50K       507
# Armed-Forces       <=50K        8
#                    >50K         1
# Craft-repair       <=50K     3165
#                    >50K       929
# Exec-managerial    <=50K     2097
#                    >50K      1968
# Farming-fishing    <=50K      877
#                    >50K       115
# Handlers-cleaners  <=50K     1283
#                    >50K        86
# Machine-op-inspct  <=50K     1751
#                    >50K       249
# Other-service      <=50K     3154
#                    >50K       137
# Priv-house-serv    <=50K      146
#                    >50K         1
# Prof-specialty     <=50K     2278
#                    >50K      1858
# Protective-serv    <=50K      438
#                    >50K       211
# Sales              <=50K     2667
#                    >50K       983
# Tech-support       <=50K      644
#                    >50K       283
# Transport-moving   <=50K     1277
#                    >50K       320
# Unknown            <=50K     1652
#                    >50K       191
# Name: salary, dtype: int64

# %%
sns.countplot(data = df, x = 'occupation', hue= 'salary');

# %% [markdown]
# **Check the percentage distribution of person in each "salary" levels by each occupation groups and visualize it with bar plot**

# %% [markdown]
# **Check the count of person in each occupation groups by "salary" levels and visualize it with countplot**

# %%
df.groupby('salary')['occupation'].value_counts(dropna = False)
# Out:
# salary  occupation
# <=50K   Adm-clerical         3261
#         Craft-repair         3165
#         Other-service        3154
#         Sales                2667
#         Prof-specialty       2278
#         Exec-managerial      2097
#         Machine-op-inspct    1751
#         Unknown              1652
#         Handlers-cleaners    1283
#         Transport-moving     1277
#         Farming-fishing       877
#         Tech-support          644
#         Protective-serv       438
#         Priv-house-serv       146
#         Armed-Forces            8
# >50K    Exec-managerial      1968
#         Prof-specialty       1858
#         Sales                 983
#         Craft-repair          929
#         Adm-clerical          507
#         Transport-moving      320
#         Tech-support          283
#         Machine-op-inspct     249
#         Protective-serv       211
#         Unknown               191
#         Other-service         137
#         Farming-fishing       115
#         Handlers-cleaners      86
#         Armed-Forces            1
#         Priv-house-serv         1
# Name: occupation, dtype: int64

# %%
sns.countplot(data = df, x = 'salary', hue= 'occupation');

# %% [markdown]
# **Check the the percentage distribution of person in each occupation groups by "salary" levels and visualize it with bar plot**

# %% [markdown]
# **Write down the conclusions you draw from your analysis**

# %% [markdown]
# **Result :** "Exec-managerial" and "Prof-specialty" occupations have a high ratio of high-level income both in the self group and in the high-income group.

# %% [markdown]
# ## race

# %% [markdown]
# **Check the count of person in each categories and visualize it with countplot**

# %%
df.race.value_counts()
# Out:
# White                 27795
# Black                  3122
# Asian-Pac-Islander     1038
# Amer-Indian-Eskimo      311
# Other                   271
# Name: race, dtype: int64

# %%
sns.countplot(data = df, x = 'race');

# %% [markdown]
# **Check the count of person in each "salary" levels by races and visualize it with countplot**

# %%
df.groupby('race')['salary'].value_counts(dropna = False)
# Out:
# race                salary
# Amer-Indian-Eskimo  <=50K       275
#                     >50K         36
# Asian-Pac-Islander  <=50K       762
#                     >50K        276
# Black               <=50K      2735
#                     >50K        387
# Other               <=50K       246
#                     >50K         25
# White               <=50K     20680
#                     >50K       7115
# Name: salary, dtype: int64

# %%
sns.countplot(data = df, x = 'race', hue = 'salary');

# %% [markdown]
# **Check the percentage distribution of person in each "salary" levels by each races and visualize it with pie plot**

# %% [markdown]
# **Check the count of person in each races by "salary" levels and visualize it with countplot**

# %%
df.groupby('salary')['race'].value_counts(dropna = False)
# Out:
# salary  race
# <=50K   White                 20680
#         Black                  2735
#         Asian-Pac-Islander      762
#         Amer-Indian-Eskimo      275
#         Other                   246
# >50K    White                  7115
#         Black                   387
#         Asian-Pac-Islander      276
#         Amer-Indian-Eskimo       36
#         Other                    25
# Name: race, dtype: int64

# %%
sns.countplot(data = df, x = 'salary', hue = 'race');

# %% [markdown]
# **Check the the percentage distribution of person in each races by "salary" levels and visualize it with bar plot**

# %% [markdown]
# **Write down the conclusions you draw from your analysis**

# %% [markdown]
# **Result :** "Asian-Pac-Islander" and "White" races has a high ratio in the self group about high-level income. "White" race has a high ratio in the high-income group about high-level income.

# %% [markdown]
# ## sex

# %% [markdown]
# **Check the count of person in each sex and visualize it with countplot**

# %%
df.sex.value_counts()
# Out:
# Male      21775
# Female    10762
# Name: sex, dtype: int64

# %%
sns.countplot( data= df, x = 'sex');

# %% [markdown]
# **Check the count of person in each "salary" levels by sex and visualize it with countplot**

# %%
df.groupby('sex')['salary'].value_counts(dropna = False)
# Out:
# sex     salary
# Female  <=50K      9583
#         >50K       1179
# Male    <=50K     15115
#         >50K       6660
# Name: salary, dtype: int64

# %%
sns.countplot( data= df, x = 'sex', hue = 'salary');

# %% [markdown]
# **Check the percentage distribution of person in each "salary" levels by each sex and visualize it with pie plot**

# %% [markdown]
# **Check the count of person in each sex by "salary" levels and visualize it with countplot**

# %%
df.groupby('salary')['sex'].value_counts(dropna = False)
# Out:
# salary  sex
# <=50K   Male      15115
#         Female     9583
# >50K    Male       6660
#         Female     1179
# Name: sex, dtype: int64

# %%
sns.countplot( data= df, x = 'salary', hue = 'sex');

# %% [markdown]
# **Check the the percentage distribution of person in each sex by "salary" levels and visualize it with pie plot**

# %% [markdown]
# **Write down the conclusions you draw from your analysis**

# %% [markdown]
# **Result :** We can easily say that males have earned more income than females.

# %% [markdown]
# ## native_country

# %% [markdown]
# **Check the count of person in each categories and visualize it with countplot**

# %% [markdown]
# **Replace the value "?" to the value "Unknown"**

# %% [markdown]
# **Decrease the number of categories in "native_country" feature as US, and Others and create a new feature with this new categorical data**

# %% [markdown]
# **Visualize the count of person in each new categories (US, Others)**

# %% [markdown]
# **Check the count of person in each "salary" levels by these new native countries (US, Others) and visualize it with countplot**

# %% [markdown]
# **Check the percentage distribution of person in each "salary" levels by each new native countries (US, Others) and visualize it with pie plot separately**

# %% [markdown]
# **Check the count of person in each these new native countries (US, Others) by "salary" levels and visualize it with countplot**

# %% [markdown]
# **Check the the percentage distribution of person in each these new native countries (US, Others) by "salary" levels and visualize it with pie plot separately**

# %% [markdown]
# **Write down the conclusions you draw from your analysis**

# %% [markdown]
# **Result :** "United States" has a high ratio of high-level income both in the self group and in the high-income group.

# %% [markdown]
# ## <p style="background-color:#47AC34; font-family:newtimeroman; color:#FFF9ED; font-size:175%; text-align:center; border-radius:10px 10px;">Other Specific Analysis Questions</p>
#
# <a id="5"></a>
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true"
# style="color:20b2aa; background-color:#47AC34" data-toggle="popover">Content</a>

# %% [markdown]
# ### 1. What is the average age of males and females by income level?

# %% [markdown]
# ### 2. What is the workclass percentages of Americans in high-level income group?

# %% [markdown]
# ### 3. What is the occupation percentages of Americans who work as "Private" workclass in high-level income group?

# %% [markdown]
# ### 4. What is the education level percentages of Asian-Pac-Islander race group in high-level income group?

# %% [markdown]
# ### 5. What is the occupation percentages of Asian-Pac-Islander race group who has a Bachelors degree in high-level income group?

# %% [markdown]
# ### 6. What is the mean of working hours per week by sex for education level, native country and marital status? Try to plot all required in one figure.

# %% [markdown]
# ## <p style="background-color:#47AC34; font-family:newtimeroman; color:#FFF9ED; font-size:175%; text-align:center; border-radius:10px 10px;">Dropping Similar & Unneccessary Features</p>
#
# <a id="6"></a>
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true"
# style="color:20b2aa; background-color:#47AC34" data-toggle="popover">Content</a>

# %% [markdown]
# ## <p style="background-color:#47AC34; font-family:newtimeroman; color:#FFF9ED; font-size:175%; text-align:center; border-radius:10px 10px;">Handling with Missing Value</p>
#
# <a id="7"></a>
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true"
# style="color:20b2aa; background-color:#47AC34" data-toggle="popover">Content</a>

# %% [markdown]
# **Check the missing values for all features basically**

# %% [markdown]
# **1. It seems that there is no missing value. But we know that "workclass", and "occupation" features have missing values as the "Unknown" string values. Examine these features in more detail.**
#
# **2. Decide if drop these "Unknown" string values or not**

# %%
# Replace "Unknown" values with NaN using numpy library

# %% [markdown]
# ## <p style="background-color:#47AC34; font-family:newtimeroman; color:#FFF9ED; font-size:175%; text-align:center; border-radius:10px 10px;">Handling with Outliers</p>
#
# <a id="8"></a>
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true"
# style="color:20b2aa; background-color:#47AC34" data-toggle="popover">Content</a>

# %% [markdown]
# ### Boxplot and Histplot for all numeric features
#
# **Plot boxplots for each numeric features at the same figure as subplots**

# %%
##df.select_dtypes(include="int64").plot(kind='box');

# %% [markdown]
# **Plot both boxplots and histograms for each numeric features at the same figure as subplots**

# %% [markdown]
# **Check the statistical values for all numeric features**

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/t3MJHDr/97.png)

# %% [markdown]
# **1. After analyzing all features, we have decided that we can't evaluate extreme values in "fnlwgt, capital_gain, capital_loss" features in the scope of outliers.**
#
# **2. So let's examine "age and hours_per_week" features and detect extreme values which could be outliers by using IQR Rule.**

# %% [markdown]
# ### age

# %%
# Find IQR defining quantile 0.25 for low level and 0.75 for high level

# %%
# Find lower and upper limit using IQR

# %%
#  It cannot be a negative age value, we need to set lower to 0.

# %%
# Define the observations whose age is greater than upper limit and sort these observations by age in descending order

# %% [markdown]
# ### hours_per_week

# %%
# Find IQR defining quantile 0.25 for low level and 0.75 for high level

# %%
# Find the lower and upper limit using IQR

# %%
# Define the observations where  hours per week are greater than upper limit and 
# sort these observations by hours per week in descending order

# %% [markdown]
# **Result :** As we see, there are number of extreme values in both "age and hours_per_week" features. But how can we know if these extreme values are outliers or not? At this point, **domain knowledge** comes to the fore.
#
# **Domain Knowledge for this dataset:**
# 1. In this dataset, all values are created according to the statements of individuals. So It can be some "data entries errors".
# 2. In addition, we have aimed to create an ML model with some restrictions as getting better performance from the ML model.
# 3. In this respect, our sample space ranges for some features are as follows.
#     - **age : 17 to 80**
#     - **hours_per_week : 7 to 70**
#     - **if somebody's age is more than 60, he/she can't work more than 60 hours in a week**

# %% [markdown]
# ### Dropping rows according to the domain knownledge

# %%
# Drop these indices defined above for age

# %%
# Drop these indices defined above for both age and hours per week

# %% [markdown]
# ## <p style="background-color:#47AC34; font-family:newtimeroman; color:#FFF9ED; font-size:175%; text-align:center; border-radius:10px 10px;">Final Step to Make the Dataset Ready for ML Models</p>
#
# <a id="9"></a>
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true"
# style="color:20b2aa; background-color:#47AC34" data-toggle="popover">Content</a>

# %% [markdown]
# ### 1. Convert all features to numeric

# %% [markdown]
# **Convert target feature (salary) to numeric (0 and 1) by using map function**

# %% [markdown]
# **Convert all features to numeric by using get_dummies function**

# %%
# What's the shape of dataframe

# %%
# What's the shape of dataframe created by dummy operation

# %% [markdown]
# ### 2. Take a look at correlation between features by utilizing power of visualizing

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/0MCPc4d/113.png)

# %% [markdown]
# <a id="10"></a>
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true"
# style="color:20b2aa; background-color:#47AC34" data-toggle="popover">Content</a>
#
# ## <p style="background-color:#47AC34; font-family:newtimeroman; color:#FFF9ED; font-size:150%; text-align:center; border-radius:10px 10px;">The End of the Project</p>
#
# <p style="text-align: center;"><img src="https://techproeducation.com/wp-content/uploads/2022/01/Calisma-Yuzeyi-1-kopya-5-1-768x126.png" class="img-fluid"
# alt="TECHPRO"></p>
#
# ## <p style="background-color:#47AC34; font-family:newtimeroman; color:#FFF9ED; font-size:100%; text-align:center; border-radius:10px 10px;">WAY TO REINVENT YOURSELF</p>
#
# ___
